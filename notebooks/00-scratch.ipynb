# %%
import xarray as xr
import matplotlib.pyplot as plt
import geopandas as gpd
from pathlib import Path

# %%
resorr_forcings_fn = Path("/tiger1/pdas47/resorr-swot/data/regulation-data/resorr_forcings.nc")
resorr_forcings_ds = xr.open_dataset(resorr_forcings_fn)
resorr_forcings_ds
# Out:
# <xarray.Dataset> Size: 459kB
# Dimensions:                     (time: 3189, node: 8)
# Coordinates:
#   * time                        (time) datetime64[ns] 26kB 2013-01-21 ... 202...
#   * node                        (node) int64 64B 0 1 2 3 4 5 6 8
# Data variables:
#     theoretical_natural_runoff  (time, node) float64 204kB ...
#     storage_change              (time, node) float64 204kB ...
#     dt                          (time) int64 26kB ...

# %%
cumberland_dams_fn = Path("/tiger1/pdas47/resorr-swot/data/cumberland_rivreg/cumberland_rivreg_pts.geojson")
cumberland_dams = gpd.read_file(cumberland_dams_fn)
cumberland_dams.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import rat

# %%
from rat.cli.rat_cli import init
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from rat.cli.rat_cli import init
#
# ImportError: cannot import name 'init' from 'rat.cli.rat_cli' (/tiger1/pdas47/resorr-swot/.rat_env/lib/python3.12/site-packages/rat/cli/rat_cli.py)

# %%
from rat.cli.rat_cli import init_func

# %%
# ?init_func
# Out:
# Signature: init_func(args)
# Docstring: <no docstring>
# File:      /tiger1/pdas47/resorr-swot/.rat_env/lib/python3.12/site-packages/rat/cli/rat_cli.py
# Type:      function
